# %% [markdown]
# <a href="https://colab.research.google.com/github/apoodwivedi/hello-world/blob/master/HA1_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt  
import io
df = pd.read_csv(io.BytesIO(uploaded['MD_COVID-19.csv']))
df_regions = df[df.columns[2:]]
df_regions
# Out:
#      Allegany  Anne_Arundel  Baltimore  ...  Calvert  Caroline  Washington
# 0         NaN             2          3  ...      NaN       NaN         NaN
# 1         NaN             1          4  ...      NaN       NaN         NaN
# 2         NaN             3          6  ...      NaN       NaN         NaN
# 3         NaN             4         10  ...      NaN       NaN         NaN
# 4         NaN             5         12  ...      1.0       NaN         NaN
# ..        ...           ...        ...  ...      ...       ...         ...
# 306    5839.0         29358      43403  ...   2899.0    1608.0     10306.0
# 307    5865.0         29710      43793  ...   2967.0    1627.0     10418.0
# 308    5888.0         29955      44057  ...   3009.0    1645.0     10495.0
# 309    5891.0         30174      44207  ...   3051.0    1652.0     10549.0
# 310    5956.0         30355      44391  ...   3099.0    1665.0     10625.0
#
# [311 rows x 7 columns]

# %%
sum_cases = df_regions.sum(axis = 0, skipna = True)
sum_cases
# Out:
# Allegany           366903.0
# Anne_Arundel      2890716.0
# Baltimore         4845533.0
# Baltimore_City    4179710.0
# Calvert            271086.0
# Caroline           169976.0
# Washington         670274.0
# dtype: float64

# %%
regions = list(sum_cases.keys())

# %%
values = []
for i in regions:
  values.append(sum_cases[i])
values
# Out:
# [366903.0, 2890716.0, 4845533.0, 4179710.0, 271086.0, 169976.0, 670274.0]

# %%
range(int(min(values)), int(max(values)))
# Out:
# range(169976, 4845533)

# %%
values_new = np.linspace(0, 4850000, num=20)
values_new = values_new.astype(int)
values_new
# Out:
# array([      0,  255263,  510526,  765789, 1021052, 1276315, 1531578,
#        1786842, 2042105, 2297368, 2552631, 2807894, 3063157, 3318421,
#        3573684, 3828947, 4084210, 4339473, 4594736, 4850000])

# %%
fig = plt.figure(figsize = (15, 8)) 
plt.bar(regions, values, width = 0.7) 
  
plt.xlabel("Regions") 
plt.ylabel("No. of cases reported (in millions)") 
plt.title("Total number of cases reported in different regions")
plt.yticks(values_new)
plt.show()

# %%
fig = plt.figure(figsize =(10, 7)) 
plt.pie(values, labels = regions) 
  
# show plot 
plt.show()

# %%
df.head()
# Out:
#    OBJECTID                    DATE  Allegany  ...  Calvert  Caroline  Washington
# 0         1  03/15/2020 10:00:00 AM       NaN  ...      NaN       NaN         NaN
# 1         2  03/16/2020 10:00:00 AM       NaN  ...      NaN       NaN         NaN
# 2         3  03/17/2020 10:00:00 AM       NaN  ...      NaN       NaN         NaN
# 3         4  03/18/2020 10:00:00 AM       NaN  ...      NaN       NaN         NaN
# 4         5  03/19/2020 10:00:00 AM       NaN  ...      1.0       NaN         NaN
#
# [5 rows x 9 columns]

# %%
for i in regions:
  df.boxplot(by ='DATE', column =[i], grid = True, figsize = (18,6))
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# ...

# %%
for i in regions:
  print('Mean number of cases for',i,'is',df[i].mean())
  print('Median number of cases for',i,'is',df[i].median())
  varianc = (df[i].std())**2
  print('Variance of number of cases for',i,'is',varianc)
  print('')
# Out:
# Mean number of cases for Allegany is 1252.2286689419795
# Median number of cases for Allegany is 388.0
# Variance of number of cases for Allegany is 3380119.224928701
#
# Mean number of cases for Anne_Arundel is 9294.906752411576
# Median number of cases for Anne_Arundel is 7700.0
# Variance of number of cases for Anne_Arundel is 56876920.25901874
#
# Mean number of cases for Baltimore is 15580.491961414791
# Median number of cases for Baltimore is 14043.0
# Variance of number of cases for Baltimore is 145022354.63138682
#
# Mean number of cases for Baltimore_City is 13439.581993569132
# Median number of cases for Baltimore_City is 13507.0
# Variance of number of cases for Baltimore_City is 96669833.39890058
#
# Mean number of cases for Calvert is 883.0162866449512
# Median number of cases for Calvert is 748.0
# Variance of number of cases for Calvert is 526711.0160737474
#
# Mean number of cases for Caroline is 559.1315789473684
# Median number of cases for Caroline is 472.0
# ...
